# %% [markdown]
# # Features based on Kothari's List

# %%
import pandas as pd
# %run "../Model/DataHelpers.ipynb"

print(f'Loading gene data - Start')
df = pd.read_csv('../Data/geneDataPreProcessed.csv')
print(f'Loading gene data - End')
# Out:
# Loading gene data - Start
# Loading gene data - End

# %%
variant = FeatureVariant.KOTHARI

# Paper 'Machine learning analysis identifies genes differentiating triple negative breast cancers'
# doi 10.1038/s41598-020-67525-1
# The article mentions 'SFRS13B' as a gene symbol.
# Cross-referencing external databases (e.g. Human Protein Atlas) indicates
# 'SRSF12' as a current alias, which is used in this dataset.

features = [ 'TBC1D9', 'GATA3', 'SLC16A6', 'ESR1', 'INPP4B', 
             'SLC44A4', 'ANXA9', 'AGR2', 'MCCC2', 'TSPAN1',
             'STBD1', 'MLPH', 'CACNA2D2', 'RARA', 'STARD3', 
             'PPP1R14C', 'SRSF12', 'LDHB', 'MFGE8', 'PSAT1' ]

# %% [markdown]
# # Send dataframe to a csv

# %%
df[features+constTargetAndMetadata].to_csv(f'../Data/interim/patient_genes_{variant}.csv', index=False)
